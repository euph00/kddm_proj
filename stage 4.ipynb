# %% [markdown]
# # CS5228 Mini Project: Customer Segmentation & Churn Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 1. Data Preprocessing

# %% [markdown]
# ### 1a. Load & Inspect

# %%
train = pd.read_csv('churn-bigml-80.csv')
test = pd.read_csv('churn-bigml-20.csv')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
train.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
print(train['Churn'].value_counts())
print(train['International plan'].value_counts())
print(train['Voice mail plan'].value_counts())
print(train['Area code'].value_counts())
print(f"Unique states: {train['State'].nunique()}")
# Out:
# Churn
# False    2278
# True      388
# Name: count, dtype: int64
# International plan
# No     2396
# Yes     270
# Name: count, dtype: int64
# Voice mail plan
# No     1933
# Yes     733
# Name: count, dtype: int64
# Area code
# 415    1318
# 510     679
# 408     669
# Name: count, dtype: int64
# Unique states: 51

# %%
train.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# **Missing values:** No missing values detected across all 2666 training samples and all 20 features, no imputation or dropping required.

# %% [markdown]
# ### 1b. Encode Categoricals

# %%
for df in [train, test]:
    df['Churn'] = df['Churn'].map({'True': 1, 'False': 0, True: 1, False: 0})
    df['International plan'] = df['International plan'].map({'Yes': 1, 'No': 0})
    df['Voice mail plan'] = df['Voice mail plan'].map({'Yes': 1, 'No': 0})

train.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415                   0                1
# 1    OH             107        415                   0                1
# 2    NJ             137        415                   0                0
# 3    OH              84        408                   1                0
# 4    OK              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# Compute full pre-drop correlation matrix (all 18 numeric features) for use in EDA section 2c
pre_drop_num_cols = train.select_dtypes(include='number').columns.drop('Churn').tolist()
corr_full = train[pre_drop_num_cols].corr()

# %% [markdown]
# The following columns are dropped before modelling from a previous EDA pass:
# - **4 charge columns** (`Total day/eve/night/intl charge`): deterministic linear transforms of their corresponding minutes columns (r = 1.000).
# - **`Area code`**: no predictive signal (churn rate is uniform across all 3 codes).
# - **`State`**: high cardinality (51 categories, ~52 samples per state on average) makes encoding impractical. Low sample count per category gives information that is potentially poorly balanced.
# - **`Voice mail plan`**: near-perfectly correlated with `Number vmail messages` (r = 0.957); the continuous count is retained as it carries more granular information.

# %%
drop_cols = ['Total day charge', 'Total eve charge', 'Total night charge', 'Total intl charge',
             'Area code', 'State', 'Voice mail plan']
for df in [train, test]:
    df.drop(columns=drop_cols, inplace=True)
print(list(train.columns))
# Out:
# ['Account length', 'International plan', 'Number vmail messages', 'Total day minutes', 'Total day calls', 'Total eve minutes', 'Total eve calls', 'Total night minutes', 'Total night calls', 'Total intl minutes', 'Total intl calls', 'Customer service calls', 'Churn']

# %% [markdown]
# ### 1c. Normalize Numerical Features
#
# Fit scaler on train only, transform both train and test.

# %%
num_cols = train.select_dtypes(include='number').columns.drop('Churn').tolist()
print(num_cols)
# Out:
# ['Account length', 'International plan', 'Number vmail messages', 'Total day minutes', 'Total day calls', 'Total eve minutes', 'Total eve calls', 'Total night minutes', 'Total night calls', 'Total intl minutes', 'Total intl calls', 'Customer service calls']

# %%
scaler = StandardScaler()
train_scaled = train.copy()
test_scaled = test.copy()

train_scaled[num_cols] = scaler.fit_transform(train[num_cols])
test_scaled[num_cols] = scaler.transform(test[num_cols])

# %%
train_scaled.to_csv('churn-bigml-processed-80.csv', index=False)
test_scaled.to_csv('churn-bigml-processed-20.csv', index=False)

# %% [markdown]
# ## 2. Exploratory Data Analysis (Training Set)

# %% [markdown]
# ### 2a. Class Balance

# %%
churn_counts = train['Churn'].value_counts()
churn_counts.plot(kind='bar', color=['steelblue', 'tomato'])
plt.xticks([0, 1], ['No Churn (0)', 'Churn (1)'], rotation=0)
plt.ylabel('Count')
plt.title('Class Distribution')
plt.tight_layout()
plt.show()
print(churn_counts / len(train))
# Out:
# Churn
# 0    0.854464
# 1    0.145536
# Name: count, dtype: float64

# %% [markdown]
# **Interpretation:** The training set is heavily imbalanced, only 14.6% of customers churned. A naive model that predicts "no churn" for every customer would still achieve 85% accuracy, making accuracy a misleading standalone metric. In the supervised learning stage we will prioritise **precision, recall, and F1-score** as primary metrics, and handle the imbalance with sub/supersampling, synthetic oversampling or loss weight.

# %% [markdown]
# ### 2b. Feature Distributions by Churn

# %%
fig, axes = plt.subplots(4, 3, figsize=(14, 12))
axes = axes.flatten()

for i, col in enumerate(num_cols):
    for label, color in [(0, 'steelblue'), (1, 'tomato')]:
        train[train['Churn'] == label][col].hist(ax=axes[i], alpha=0.6, color=color, bins=30, label=str(label))
    axes[i].set_title(col, fontsize=8)
    axes[i].legend(fontsize=7)

for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.suptitle('Feature Distributions by Churn (blue=No, red=Yes)', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation:** Several features show meaningful distributional differences between churn (red) and non-churn (blue) groups:
# - **Total day minutes:** The churn distribution is shifted noticeably right. Heavy daytime users are more likely to leave, possibly due to higher bills.
# - **Customer service calls:** Churn customers cluster at higher values (3+), strongly suggesting that repeated service contact reflects unresolved dissatisfaction.
# - **Number vmail messages:** Non-churn customers tend to have more voicemail messages, consistent with the negative correlation seen in Section 2d.
# - **Total intl minutes:** A slight rightward shift for churn customers hints that high international usage may drive dissatisfaction, possibly tied to international plan pricing.

# %% [markdown]
# ### 2c. Collinearity Analysis

# %%
# Full pre-drop correlation matrix (18 numeric features, computed before dropping redundant columns)
plt.figure(figsize=(18, 14))
sns.heatmap(corr_full, annot=True, fmt='.2f', cmap='coolwarm', center=0, square=True, annot_kws={'size': 7})
plt.title('Feature Correlation Heatmap — All 18 Numeric Features (Pre-Drop)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation (Pre-Drop):** The full heatmap covers all 18 numeric features from the original 19 (State is excluded as it is non-numeric and cannot appear in a Pearson correlation matrix). Two types of redundancy are visible:
#
# 1. **Perfect linear collinearity (r = 1.000):** Four minute/charge pairs are exact linear transforms of each other: `Total day minutes` and `Total day charge`, `Total eve minutes` and `Total eve charge`, `Total night minutes` and `Total night charge`, `Total intl minutes` and `Total intl charge`. Each charge is simply `minutes × fixed rate`, contributing zero independent information.
#
# 2. **Near-perfect correlation (r = 0.957):** `Voice mail plan` and `Number vmail messages`. Customers with a voicemail plan almost always have voicemail messages, binary plan indicator is almost entirely redundant with the count.
#
# Outside these pairs, all other feature-to-feature correlations are |r| < 0.05, indicating the remaining features are largely orthogonal. Based on these findings, the 4 charge columns and `Voice mail plan` are dropped in preprocessing.

# %%
# Post-drop correlation matrix — confirms clean feature set
corr = train[num_cols].corr()
plt.figure(figsize=(12, 9))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0, square=True)
plt.title('Feature Correlation Heatmap — Retained Features (Post-Drop)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation (Post-Drop):** After removing all redundant features, the correlation matrix confirms that the retained 12 features are largely independent. Almost all pairwise correlations are |r| < 0.05. No significant collinearity remains, giving confidence that each retained feature contributes independent signal to the models.

# %% [markdown]
# ### 2d. Feature-vs-Churn Correlations

# %%
from scipy.stats import pointbiserialr

correlations = {}
for col in num_cols:
    r, _ = pointbiserialr(train['Churn'], train[col])
    correlations[col] = r

corr_series = pd.Series(correlations).sort_values(key=abs, ascending=False)
corr_series.plot(kind='barh', figsize=(8, 5))
plt.axvline(0, color='black', linewidth=0.8)
plt.title('Point-Biserial Correlation with Churn')
plt.tight_layout()
plt.show()
print(corr_series)
# Out:
# International plan        0.277489
# Customer service calls    0.202590
# Total day minutes         0.195688
# Number vmail messages    -0.086474
# Total intl minutes        0.086204
# Total eve minutes         0.072906
# Total intl calls         -0.069882
# Total night minutes       0.033639
# Total day calls           0.018290
# Account length            0.017728
# Total night calls         0.012262
# Total eve calls          -0.001539
# dtype: float64

# %% [markdown]
# **Interpretation:** Ranking features by absolute point-biserial correlation with churn identifies the strongest individual predictors:
#
# - **Top 3 predictive features:** `International plan` (r = 0.277), `Customer service calls` (r = 0.203), and `Total day minutes` (r = 0.196). These provide the clearest signal for distinguishing churners from non-churners.
# - **Moderate signal:** `Number vmail messages` (r ≈ −0.086), `Total intl minutes` (r ≈ 0.086), `Total eve minutes` (r ≈ 0.073), and `Total intl calls` (r ≈ −0.070) show small but non-negligible associations with churn.
# - **Near-zero features:** Call count columns (`Total day/eve/night calls`) and `Account length` carry essentially no linear signal for churn prediction.

# %%
top3 = corr_series.abs().nlargest(3).index.tolist()
print(f"Top 3 features: {top3}")
print()
print(corr_series.abs().nlargest(3).round(3))
# Out:
# Top 3 features: ['International plan', 'Customer service calls', 'Total day minutes']
#
# International plan        0.277
# Customer service calls    0.203
# Total day minutes         0.196
# dtype: float64

# %% [markdown]
# **Top features summary:** The two most discriminative features are `International plan` and `Customer service calls`, capturing plan-based dissatisfaction and service friction respectively. Adding `Total day minutes` as the third feature introduces a usage-volume dimension. High daytime usage correlates with higher bills and greater churn risk.

# %% [markdown]
# ### 2e. Customer Service Calls — Churn Rate by Count

# %%
cs_churn = train.groupby('Customer service calls')['Churn'].mean()
cs_counts = train['Customer service calls'].value_counts().sort_index()

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

cs_churn.plot(kind='bar', ax=axes[0], color='tomato')
axes[0].set_title('Churn Rate by Customer Service Calls')
axes[0].set_ylabel('Churn Rate')
axes[0].tick_params(axis='x', rotation=0)

cs_counts.plot(kind='bar', ax=axes[1], color='steelblue')
axes[1].set_title('Customer Count by Service Calls')
axes[1].set_ylabel('Count')
axes[1].tick_params(axis='x', rotation=0)

plt.tight_layout()
plt.show()
print(cs_churn.round(3))
# Out:
# Customer service calls
# 0    0.142
# 1    0.105
# 2    0.102
# 3    0.106
# 4    0.481
# 5    0.592
# 6    0.588
# 7    0.625
# 8    1.000
# 9    1.000
# Name: Churn, dtype: float64

# %% [markdown]
# **Interpretation:** Customer service calls reveals a threshold effect: churn rate rises steeply and non-linearly with the number of calls made. Customers who called **4 or more times** show dramatically elevated churn rates, suggesting a tipping point beyond which unresolved issues become a decisive reason to leave. This non-linear pattern means linear models may underweight this feature.

# %% [markdown]
# ### 2f. Categorical Feature Breakdown

# %%
churn_rate = train.groupby('International plan')['Churn'].mean()
churn_rate.index = ['No', 'Yes']
churn_rate.plot(kind='bar', color='tomato', figsize=(5, 4))
plt.title('Churn Rate by International Plan')
plt.ylabel('Churn Rate')
plt.ylim(0, 0.5)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation:**
# - **International plan** has a dramatic effect: customers with the plan churn at ~44% vs ~11% without, nearly **4x higher**. This is the single strongest categorical predictor of churn in the dataset, likely reflecting pricing dissatisfaction among heavy international callers.
# - **Voice mail plan** (dropped due to redundancy with `Number vmail messages`): pre-drop analysis showed customers without a voicemail plan churned at ~17% vs ~8% with one, a meaningful protective effect captured by the retained `Number vmail messages` feature.
# - **Area code** (dropped): showed essentially uniform churn rates across all three codes (~14%), confirming it carries no predictive signal.

# %% [markdown]
# ## 3. Unsupervised Learning: Customer Segmentation

# %%
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
import sys
# !{sys.executable} -m pip install umap-learn
from umap import UMAP

# %%
X = train_scaled[num_cols].values

reducer_3d = UMAP(n_components=3, random_state=42, n_neighbors=15, min_dist=0.1)
X_umap = reducer_3d.fit_transform(X)

fig = plt.figure(figsize=(14, 6))

ax1 = fig.add_subplot(121, projection='3d')
colors = ['steelblue' if v == 0 else 'tomato' for v in train['International plan'].values]
ax1.scatter(X_umap[:, 0], X_umap[:, 1], X_umap[:, 2], c=colors, alpha=0.4, s=5)
ax1.set_title('International Plan (blue=No, red=Yes)')
ax1.set_xlabel('UMAP-1')
ax1.set_ylabel('UMAP-2')
ax1.set_zlabel('UMAP-3')

ax2 = fig.add_subplot(122, projection='3d')
colors = ['steelblue' if v == 0 else 'tomato' for v in train['Churn'].values]
ax2.scatter(X_umap[:, 0], X_umap[:, 1], X_umap[:, 2], c=colors, alpha=0.4, s=5)
ax2.set_title('Churn (blue=No, red=Yes)')
ax2.set_xlabel('UMAP-1')
ax2.set_ylabel('UMAP-2')
ax2.set_zlabel('UMAP-3')

plt.suptitle('UMAP 3D Projection of Training Data')
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# ### 3a. K-Means

# %%
inertias, silhouettes = [], []
K_range = range(2, 11)

for k in K_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = km.fit_predict(X)
    inertias.append(km.inertia_)
    silhouettes.append(silhouette_score(X, labels))

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(list(K_range), inertias, 'o-')
axes[0].set_xlabel('K')
axes[0].set_ylabel('Inertia')
axes[0].set_title('Elbow Method')

axes[1].plot(list(K_range), silhouettes, 'o-', color='tomato')
axes[1].set_xlabel('K')
axes[1].set_ylabel('Silhouette Score')
axes[1].set_title('Silhouette Score')

plt.tight_layout()
plt.show()

# for k, sil in zip(K_range, silhouettes):
#     print(f"K={k}: silhouette={sil:.4f}")

# %% [markdown]
# **Optimal K:** The elbow curve is smooth with no distinct kink, and the silhouette score peaks at **K=2** (0.204) and drops sharply to 0.116 at K=3. Both metrics point to K=2. However, the UMAP 3D projection above clearly shows **three** well-separated clusters in the data.
#
# The discrepancy arises from a fundamental difference in what each method measures. Silhouette and elbow both operate on **global Euclidean distances in 12D**: K=2 captures the dominant variance (the International plan binary split) very efficiently, and adding a 3rd cluster only marginally improves within-cluster compactness relative to the cost in inter-cluster separation, so silhouette drops. UMAP, on the other hand, builds a **local neighborhood graph** and is sensitive to density gaps. It detects that `Number vmail messages` is strongly bimodal (0 vs ~30), meaning customers with and without voicemail have very few mutual nearest neighbors, creating a topological separation that is real but small in global L2 terms.
#
# We therefore select **K=3**, guided by the UMAP evidence. The metric-optimal K=2 is acknowledged but treated as an artefact of the dominant binary feature overwhelming the Euclidean distance measure.

# %%
optimal_k = 3  # UMAP 3D reveals 3 clusters; see interpretation above

km_final = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
km_labels = km_final.fit_predict(X)

# Heatmap: cluster means in scaled space (deviation from population average)
cluster_profile = train_scaled.assign(Cluster=km_labels).groupby('Cluster')[num_cols].mean()

plt.figure(figsize=(12, max(3, optimal_k + 1)))
sns.heatmap(cluster_profile, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('K-Means Cluster Profiles (mean of scaled features; 0 = population average)')
plt.tight_layout()
plt.show()

# print("Cluster sizes:", pd.Series(km_labels).value_counts().sort_index().to_dict())
# print("\nUnscaled cluster means:")
# print(train.assign(Cluster=km_labels).groupby('Cluster')[num_cols].mean().round(2))

# %%
# Identify which cluster is which based on feature means
means = train.assign(Cluster=km_labels).groupby('Cluster')[['International plan', 'Number vmail messages']].mean()
intl_cluster = means['International plan'].idxmax()
vmail_cluster = means.drop(intl_cluster)['Number vmail messages'].idxmax()
standard_cluster = [k for k in range(optimal_k) if k not in [intl_cluster, vmail_cluster]][0]

cluster_names = {intl_cluster: 'Intl Plan subscribers', vmail_cluster: 'Voicemail users', standard_cluster: 'Standard users'}
cluster_colors = {intl_cluster: 'tomato', vmail_cluster: 'mediumseagreen', standard_cluster: 'steelblue'}

fig = plt.figure(figsize=(14, 6))

ax1 = fig.add_subplot(121, projection='3d')
for k in range(optimal_k):
    mask = km_labels == k
    ax1.scatter(X_umap[mask, 0], X_umap[mask, 1], X_umap[mask, 2],
                c=cluster_colors[k], alpha=0.4, s=5, label=cluster_names[k])
ax1.set_title('K-Means Cluster Assignment')
ax1.set_xlabel('UMAP-1')
ax1.set_ylabel('UMAP-2')
ax1.set_zlabel('UMAP-3')
ax1.legend()

ax2 = fig.add_subplot(122, projection='3d')
vmail_vals = train['Number vmail messages'].values
sc = ax2.scatter(X_umap[:, 0], X_umap[:, 1], X_umap[:, 2],
                 c=vmail_vals, cmap='viridis', alpha=0.4, s=5)
plt.colorbar(sc, ax=ax2, label='# Vmail Messages', shrink=0.6)
ax2.set_title('Colored by Number vmail messages')
ax2.set_xlabel('UMAP-1')
ax2.set_ylabel('UMAP-2')
ax2.set_zlabel('UMAP-3')

plt.suptitle('UMAP 3D — K-Means Cluster Identity')
plt.tight_layout()
plt.show()

# %%
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for k in range(optimal_k):
    mask = km_labels == k
    axes[0].scatter(X_pca[mask, 0], X_pca[mask, 1], alpha=0.4, s=10,
                    color=cluster_colors[k], label=cluster_names[k])
axes[0].set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.1%} variance)')
axes[0].set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.1%} variance)')
axes[0].set_title('K-Means Clusters — PCA 2D Projection')
axes[0].legend()

churn_by_cluster = train.assign(Cluster=km_labels).groupby('Cluster')['Churn'].mean()
bar_colors = [cluster_colors[k] for k in churn_by_cluster.index]
churn_by_cluster.index = [cluster_names[k] for k in churn_by_cluster.index]
churn_by_cluster.plot(kind='bar', ax=axes[1], color=bar_colors)
axes[1].axhline(train['Churn'].mean(), color='black', linestyle='--', linewidth=1, label='Overall mean')
axes[1].set_title('Churn Rate per K-Means Cluster')
axes[1].set_ylabel('Churn Rate')
axes[1].set_xlabel('')
axes[1].tick_params(axis='x', rotation=15)
axes[1].legend()

plt.tight_layout()
plt.show()
print("Churn rate per cluster:")
print(churn_by_cluster.round(3))
# Out:
# Churn rate per cluster:
# Standard users           0.133
# Voicemail users          0.057
# Intl Plan subscribers    0.437
# Name: Churn, dtype: float64

# %% [markdown]
# **Cluster Interpretation:** K=3 produces three clearly interpretable segments, driven entirely by the two binary-like features `International plan` and `Number vmail messages` (bimodal at 0 vs ~30):
#
# - **Cluster 2: International Plan subscribers** (270 customers, 10%): Every customer in this cluster has an international plan (mean = 1.0). All other feature means are close to the population average. Churn rate: **43.7%**, nearly 3× the overall rate of 14.6%. This is the highest-risk segment.
#
# - **Cluster 1: Voicemail users** (637 customers, 24%): No international plan (mean = 0.0), but high voicemail engagement (mean = 29.7 messages). All usage metrics are near-average. Churn rate: **5.7%**, the most loyal segment, less than half the overall rate. Voicemail engagement appears to act as a product "stickiness" signal.
#
# - **Cluster 0: Standard users** (1759 customers, 66%): No international plan, no voicemail (mean = 0.14 messages). Represents the majority baseline segment with near-average usage across all features. Churn rate: **13.3%**, close to the overall average.
#
# The segmentation is almost entirely driven by two features; all other usage metrics (day minutes, call counts, etc.) are nearly identical across clusters. The UMAP 3D and K-Means agree perfectly on this structure once K=3 is used. Notably, churn is concentrated in the International Plan cluster and largely absent from the Voicemail cluster, suggesting that plan type and voicemail adoption are stronger determinants of churn risk than raw usage volume.

# %% [markdown]
# ### 3b. DBSCAN
#
# DBSCAN is applied to the 12D scaled feature space to test whether the three K-Means clusters correspond to genuine density-based groups.

# %%
# k-distance plot on raw 12D features to guide eps selection
nbrs = NearestNeighbors(n_neighbors=5).fit(X)
dists, _ = nbrs.kneighbors(X)
k_dists = np.sort(dists[:, -1])[::-1]

plt.figure(figsize=(8, 4))
plt.plot(k_dists)
plt.xlabel('Points sorted by distance')
plt.ylabel('5-NN distance')
plt.title('k-Distance Graph (k=5) on 12D Feature Space')
plt.tight_layout()
plt.show()

# --- DBSCAN ---
eps = 3
min_samples = 10
# --------------

db = DBSCAN(eps=eps, min_samples=min_samples).fit(X)
db_labels = db.labels_

n_clusters = len(set(db_labels)) - (1 if -1 in db_labels else 0)
n_noise = (db_labels == -1).sum()
print(f"DBSCAN (eps={eps}, min_samples={min_samples}): {n_clusters} clusters, {n_noise} noise ({n_noise/len(db_labels):.1%})")
print("Cluster sizes:", pd.Series(db_labels).value_counts().sort_index().to_dict())

# Paint DBSCAN labels onto UMAP + churn bar chart
fig = plt.figure(figsize=(14, 6))

ax1 = fig.add_subplot(121, projection='3d')
for label in sorted(set(db_labels)):
    mask = db_labels == label
    name = 'Noise' if label == -1 else f'Cluster {label}'
    ax1.scatter(X_umap[mask, 0], X_umap[mask, 1], X_umap[mask, 2],
                alpha=0.2 if label == -1 else 0.5, s=5, label=name)
ax1.set_title(f'DBSCAN Labels on UMAP (eps={eps}, min_samples={min_samples})')
ax1.set_xlabel('UMAP-1')
ax1.set_ylabel('UMAP-2')
ax1.set_zlabel('UMAP-3')
ax1.legend()

ax2 = fig.add_subplot(122)
churn_db = train.assign(Label=db_labels).groupby('Label')['Churn'].mean()
churn_db.index = ['Noise' if i == -1 else f'Cluster {i}' for i in churn_db.index]
churn_db.plot(kind='bar', ax=ax2, color='tomato')
ax2.axhline(train['Churn'].mean(), color='black', linestyle='--', linewidth=1, label='Overall mean')
ax2.set_title('Churn Rate per DBSCAN Label')
ax2.set_ylabel('Churn Rate')
ax2.tick_params(axis='x', rotation=15)
ax2.legend()

plt.tight_layout()
plt.show()
print("\nChurn rate:", churn_db.round(3).to_dict())
# Out:
# DBSCAN (eps=3, min_samples=10): 2 clusters, 73 noise (2.7%)
# Cluster sizes: {-1: 73, 0: 2362, 1: 231}
# Churn rate: {'Noise': 0.356, 'Cluster 0': 0.11, 'Cluster 1': 0.437}

# %%
# Verify density mismatch: compare mean 5-NN distance within each K-Means cluster
print("Mean 5-NN distance within each K-Means cluster (lower = denser):")
for k in range(optimal_k):
    X_cluster = X[km_labels == k]
    nbrs_k = NearestNeighbors(n_neighbors=5).fit(X_cluster)
    d, _ = nbrs_k.kneighbors(X_cluster)
    mean_dist = d[:, -1].mean()
    print(f"  {cluster_names[k]} (n={(km_labels == k).sum()}): {mean_dist:.3f}")
# Out:
# Mean 5-NN distance within each K-Means cluster (lower = denser):
#   Standard users (n=1759): 2.044
#   Voicemail users (n=637): 2.350
#   Intl Plan subscribers (n=270): 2.751

# %% [markdown]
# **DBSCAN Findings:**
#
# From grid search, no combination of `eps` and `min_samples` tested was able to reproduce the three-cluster structure identified by K-Means and confirmed visually by UMAP. DBSCAN consistently either merged all customers into one large cluster or fragmented them into many small ones. There are some parameter combinations that split the data into 2 clusters as seen above, but nothing that allows for 3 clusters.
#
# **Density analysis:** The mean within-cluster 5-NN distances (Standard: 2.044, Voicemail: 2.350, Intl Plan: 2.751) reveal that the three clusters have meaningfully different densities. The International Plan cluster is ~35% sparser than Standard users. This partially explains DBSCAN's difficulty: a single global `eps` must simultaneously serve all three clusters, but the `eps` that keeps the sparse Intl Plan cluster intact is too large for the other 2 clusters, causing merging.
#
# **The deeper issue:** The density difference alone does not fully explain the failure as a 35% difference is not extreme. We propose that the fundamental mismatch is between the cluster structure in this dataset and what each algorithm is designed to find.
#
# The three groups are separated almost entirely by two features `International plan` and `Number vmail messages` while the remaining 10 features are nearly identical across all clusters. K-Means is unaffected by these irrelevant features: when assigning a point to a centroid, those 10 dimensions contribute equally to the distance from every centroid, so they cancel out. The assignment is determined by the 2 discriminating dimensions alone.
#
# DBSCAN does not benefit from this cancellation. It asks whether there is a density drop at the cluster boundary, which requires that points in different clusters are farther apart in absolute distance than points within the same cluster. With 10 shared dimensions pulling points together regardless of cluster membership, the boundary between groups in 12D space is a gradual transition in density rather than a sharp gap. DBSCAN cannot find a threshold that cleanly separates them.
#
# **Conclusion:** The clusters in this dataset are **centroid-separable but not density-separable**. K-Means is the appropriate algorithm for this structure. However, DBSCAN's failure is itself informative, as it confirms that the segmentation reflects differences in specific feature values rather than isolated density regions in the full feature space.

# %% [markdown]
# ## 4. Supervised Learning: Churn Prediction

# %% [markdown]
# ### 4a. Model Setup
#
# We train three complementary classifiers on the **training subset only**:
# - Logistic Regression (interpretable linear baseline)
# - Decision Tree (non-linear rule learner)
# - Random Forest (ensemble baseline)
#
# Given the class imbalance (~14.6% churn), all models use `class_weight='balanced'`. Hyperparameter tuning is performed via stratified 5-fold CV on training data only, with **F1-score** as the optimization target.

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             confusion_matrix, classification_report, roc_auc_score,
                             average_precision_score, roc_curve, precision_recall_curve)

X_train = train_scaled[num_cols]
y_train = train_scaled['Churn'].astype(int)
X_test = test_scaled[num_cols]
y_test = test_scaled['Churn'].astype(int)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

model_spaces = {
    'Logistic Regression': {
        'estimator': LogisticRegression(class_weight='balanced', max_iter=5000, random_state=42),
        'param_grid': {
            'model__C': [0.01, 0.1, 1, 10],
            'model__solver': ['lbfgs'],
            'model__penalty': ['l2']
        }
    },
    'Decision Tree': {
        'estimator': DecisionTreeClassifier(class_weight='balanced', random_state=42),
        'param_grid': {
            'model__max_depth': [3, 5, 8, None],
            'model__min_samples_split': [2, 10, 30],
            'model__min_samples_leaf': [1, 5, 10],
            'model__criterion': ['gini', 'entropy']
        }
    },
    'Random Forest': {
        'estimator': RandomForestClassifier(class_weight='balanced', random_state=42, n_jobs=-1),
        'param_grid': {
            'model__n_estimators': [200, 400],
            'model__max_depth': [None, 8, 16],
            'model__min_samples_split': [2, 10],
            'model__min_samples_leaf': [1, 5],
            'model__max_features': ['sqrt', 'log2']
        }
    }
}

print('Train shape:', X_train.shape, '| Test shape:', X_test.shape)
print('Train churn rate:', round(y_train.mean(), 4), '| Test churn rate:', round(y_test.mean(), 4))
# Out:
# Train shape: (2666, 12) | Test shape: (667, 12)
# Train churn rate: 0.1455 | Test churn rate: 0.1424

# %% [markdown]
# ### 4b. Hyperparameter Optimization (Train CV only)

# %%
def get_scores(model, X):
    if hasattr(model, 'predict_proba'):
        return model.predict_proba(X)[:, 1]
    if hasattr(model, 'decision_function'):
        raw = model.decision_function(X)
        return (raw - raw.min()) / (raw.max() - raw.min() + 1e-12)
    return model.predict(X)

def evaluate_split(model, X, y):
    y_pred = model.predict(X)
    y_score = get_scores(model, X)
    return {
        'accuracy': accuracy_score(y, y_pred),
        'precision': precision_score(y, y_pred, zero_division=0),
        'recall': recall_score(y, y_pred, zero_division=0),
        'f1': f1_score(y, y_pred, zero_division=0),
        'roc_auc': roc_auc_score(y, y_score),
        'pr_auc': average_precision_score(y, y_score),
        'cm': confusion_matrix(y, y_pred),
        'report': classification_report(y, y_pred, digits=4, zero_division=0),
        'y_score': y_score
    }

best_models = {}
results = []
curve_data = {}

for model_name, cfg in model_spaces.items():
    pipe = Pipeline([('model', cfg['estimator'])])
    gs = GridSearchCV(estimator=pipe, param_grid=cfg['param_grid'], scoring='f1', cv=cv, n_jobs=-1)
    gs.fit(X_train, y_train)

    best_model = gs.best_estimator_
    best_models[model_name] = best_model

    train_metrics = evaluate_split(best_model, X_train, y_train)
    test_metrics = evaluate_split(best_model, X_test, y_test)

    fpr, tpr, _ = roc_curve(y_test, test_metrics['y_score'])
    pr_precision, pr_recall, _ = precision_recall_curve(y_test, test_metrics['y_score'])
    curve_data[model_name] = {'fpr': fpr, 'tpr': tpr, 'pr_precision': pr_precision, 'pr_recall': pr_recall}

    results.append({
        'Model': model_name,
        'Best Params': gs.best_params_,
        'CV Best F1': gs.best_score_,
        'Train Accuracy': train_metrics['accuracy'],
        'Train Precision': train_metrics['precision'],
        'Train Recall': train_metrics['recall'],
        'Train F1': train_metrics['f1'],
        'Test Accuracy': test_metrics['accuracy'],
        'Test Precision': test_metrics['precision'],
        'Test Recall': test_metrics['recall'],
        'Test F1': test_metrics['f1'],
        'Test ROC-AUC': test_metrics['roc_auc'],
        'Test PR-AUC': test_metrics['pr_auc'],
        'Train CM': train_metrics['cm'],
        'Test CM': test_metrics['cm'],
        'Train Report': train_metrics['report'],
        'Test Report': test_metrics['report']
    })

results_df = pd.DataFrame(results).sort_values('Test F1', ascending=False).reset_index(drop=True)
display(results_df[['Model', 'CV Best F1',
                    'Train Accuracy', 'Train Precision', 'Train Recall', 'Train F1',
                    'Test Accuracy', 'Test Precision', 'Test Recall', 'Test F1',
                    'Test ROC-AUC', 'Test PR-AUC',
                    'Best Params']])
# Out:
#                  Model  CV Best F1  Train Accuracy  Train Precision  \
# 0        Random Forest    0.811325        0.966992         0.901070
# 1        Decision Tree    0.754905        0.941485         0.780193
# 2  Logistic Regression    0.474407        0.768942         0.358561
#
#    Train Recall  Train F1  Test Accuracy  Test Precision  Test Recall  \
# 0      0.868557  0.884514       0.940030        0.789474     0.789474
# 1      0.832474  0.805486       0.929535        0.726415     0.810526
# 2      0.744845  0.484087       0.784108        0.373057     0.757895
#
#     Test F1  Test ROC-AUC  Test PR-AUC  \
# 0  0.789474      0.918366     0.859757
# 1  0.766169      0.899696     0.766660
# 2  0.500000      0.825212     0.411930
#
#                                          Best Params
# 0  {'model__max_depth': 8, 'model__max_features':...
# 1  {'model__criterion': 'entropy', 'model__max_de...
# 2  {'model__C': 0.01, 'model__penalty': 'l2', 'mo...

# %% [markdown]
# ### 4c. Performance Visualizations (4 figure categories)
#
# We report four complementary visualization types:
# 1. Test metric comparison across models
# 2. Test confusion matrices
# 3. ROC curves
# 4. Precision-Recall curves

# %%
metric_cols = ['Test Precision', 'Test Recall', 'Test F1', 'Test ROC-AUC', 'Test PR-AUC']
plot_df = results_df[['Model'] + metric_cols].melt(id_vars='Model', var_name='Metric', value_name='Score')

plt.figure(figsize=(11, 5))
sns.barplot(data=plot_df, x='Model', y='Score', hue='Metric')
plt.ylim(0, 1.05)
plt.title('Model Comparison on Test Set Metrics')
plt.ylabel('Score')
plt.xlabel('')
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, len(results_df), figsize=(5 * len(results_df), 4))
if len(results_df) == 1:
    axes = np.array([axes])

for i, row in results_df.iterrows():
    sns.heatmap(row['Test CM'], annot=True, fmt='d', cmap='Oranges', cbar=False, ax=axes[i])
    axes[i].set_title(f"{row['Model']}\nTest Confusion Matrix")
    axes[i].set_xlabel('Predicted')
    axes[i].set_ylabel('Actual')

plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 5))
for _, row in results_df.iterrows():
    name = row['Model']
    d = curve_data[name]
    plt.plot(d['fpr'], d['tpr'], label=f"{name} (AUC={row['Test ROC-AUC']:.3f})")
plt.plot([0, 1], [0, 1], 'k--', linewidth=1)
plt.title('ROC Curves (Test Set)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.tight_layout()
plt.show()

baseline = y_test.mean()
plt.figure(figsize=(6, 5))
for _, row in results_df.iterrows():
    name = row['Model']
    d = curve_data[name]
    plt.plot(d['pr_recall'], d['pr_precision'], label=f"{name} (AP={row['Test PR-AUC']:.3f})")
plt.axhline(baseline, color='gray', linestyle='--', linewidth=1, label=f'Baseline={baseline:.3f}')
plt.title('Precision-Recall Curves (Test Set)')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.show()

for row in results:
    print('=' * 80)
    print(row['Model'])
    print('-' * 80)
    print('Train classification report:')
    print(row['Train Report'])
    print('Test classification report:')
    print(row['Test Report'])
# Out:
# ...
# Logistic Regression
# --------------------------------------------------------------------------------
# Train classification report:
#               precision    recall  f1-score   support
#
#            0     0.9468    0.7730    0.8511      2278
#            1     0.3586    0.7448    0.4841       388
#
#     accuracy                         0.7689      2666
#    macro avg     0.6527    0.7589    0.6676      2666
# weighted avg     0.8612    0.7689    0.7977      2666
#
# Test classification report:
#               precision    recall  f1-score   support
#
#            0     0.9515    0.7885    0.8623       572
#            1     0.3731    0.7579    0.5000        95
#
#     accuracy                         0.7841       667
#    macro avg     0.6623    0.7732    0.6812       667
# weighted avg     0.8691    0.7841    0.8107       667
#
# ...
# Decision Tree
# --------------------------------------------------------------------------------
# Train classification report:
# ...

# %% [markdown]
# **Performance Interpretation (Method):**
#
# - We prioritise **F1-score** over raw accuracy due to class imbalance.
# - We compare models from four views: threshold metrics, confusion matrix, ROC-AUC, and PR-AUC.
# - In churn prediction, PR-AUC and Recall are especially important for reducing missed churners.

# %% [markdown]
# ### 4d. Model-Level Feature Signals
#
# To connect supervised results back to business interpretation, we inspect feature contribution from the best linear and tree-based models.

# %%
# Logistic Regression coefficients
if 'Logistic Regression' in best_models:
    lr = best_models['Logistic Regression'].named_steps['model']
    lr_coef = pd.Series(lr.coef_.ravel(), index=num_cols).sort_values()

    plt.figure(figsize=(8, 6))
    lr_coef.plot(kind='barh', color=['tomato' if v > 0 else 'steelblue' for v in lr_coef.values])
    plt.axvline(0, color='black', linewidth=1)
    plt.title('Logistic Regression Coefficients (standardized features)')
    plt.xlabel('Coefficient')
    plt.tight_layout()
    plt.show()

# Random Forest feature importance
if 'Random Forest' in best_models:
    rf = best_models['Random Forest'].named_steps['model']
    rf_imp = pd.Series(rf.feature_importances_, index=num_cols).sort_values(ascending=False)

    plt.figure(figsize=(8, 6))
    rf_imp.head(12).sort_values().plot(kind='barh', color='mediumseagreen')
    plt.title('Random Forest Feature Importance (Top 12)')
    plt.xlabel('Importance')
    plt.tight_layout()
    plt.show()

    print('Top 5 RF features:')
    print(rf_imp.head(5).round(4))
# Out:
# Top 5 RF features:
# Total day minutes         0.2647
# Customer service calls    0.1993
# International plan        0.1353
# Total eve minutes         0.0764
# Total intl minutes        0.0596
# dtype: float64

# %% [markdown]
# **Interpretation:**
#
# - Compare Stage 4 top predictive signals with Stage 2 correlations (`International plan`, `Customer service calls`, `Total day minutes`) to validate consistency between EDA and model learning.
# - If a feature is consistently high across Logistic and Random Forest analyses, it can be treated as a robust churn driver candidate.
# - These signals should be translated into action: e.g., proactive outreach to high-service-call customers, and targeted retention offers for international-plan subscribers.

# %%
display(results_df)
# Out:
#                  Model                                        Best Params  \
# 0        Random Forest  {'model__max_depth': 8, 'model__max_features':...
# 1        Decision Tree  {'model__criterion': 'entropy', 'model__max_de...
# 2  Logistic Regression  {'model__C': 0.01, 'model__penalty': 'l2', 'mo...
#
#    CV Best F1  Train Accuracy  Train Precision  Train Recall  Train F1  \
# 0    0.811325        0.966992         0.901070      0.868557  0.884514
# 1    0.754905        0.941485         0.780193      0.832474  0.805486
# 2    0.474407        0.768942         0.358561      0.744845  0.484087
#
#    Test Accuracy  Test Precision  Test Recall   Test F1  Test ROC-AUC  \
# 0       0.940030        0.789474     0.789474  0.789474      0.918366
# 1       0.929535        0.726415     0.810526  0.766169      0.899696
# 2       0.784108        0.373057     0.757895  0.500000      0.825212
#
#    Test PR-AUC                  Train CM                 Test CM  \
# ...

# %% [markdown]
# ### 4e. Final Model Selection and Summary\n\n**Performance Interpretation (Final):**
#
# The three supervised models show a clear ranking on the held-out test set. **Random Forest** is the best overall model, achieving the highest F1-score (**0.789**), ROC-AUC (**0.918**), and PR-AUC (**0.860**), with balanced precision/recall (**0.789 / 0.789**) and strong accuracy (**0.940**).
#
# **Decision Tree** is the second-best model (Test F1 = **0.766**, ROC-AUC = **0.900**, PR-AUC = **0.767**). It gives the highest recall (**0.811**) among the three models, which may be operationally useful when the priority is to miss fewer churners.
#
# **Logistic Regression** underperforms substantially (Test F1 = **0.500**, PR-AUC = **0.412**), indicating that churn boundaries in this dataset are not well captured by a simple linear decision function.
#
# From a generalization perspective, Random Forest shows a moderate train-test gap (Train F1 = **0.885** vs Test F1 = **0.789**), suggesting some overfitting but still acceptable robustness. Decision Tree is slightly more conservative (Train F1 = **0.805** vs Test F1 = **0.766**) with lower absolute performance.
#
# **Model choice:** For balanced churn prediction performance, we select **Random Forest** as the final model. For recall-prioritized intervention workflows, **Decision Tree** can be used as an auxiliary benchmark.
